# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
#Create list for holding cities
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique, add to the cities list
    if city not in cities:
        cities.append(city)
        
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 746

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=163f186b130ef1b2ab58ec34b959f3d3

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | lensk
# Processing Record 3 of Set 1 | rosetta
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | vallenar
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | brae
# Processing Record 10 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 1 | urumqi
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | poronaysk
# Processing Record 14 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | quthing
# Processing Record 17 of Set 1 | bridlington
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | katsuura
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | key west
# Processing Record 22 of Set 1 | collie
# Processing Record 23 of Set 1 | kahului
# Processing Record 24 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | chumikan
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | trinidad
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | novobelokatay
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | sao paulo de olivenca
# Processing Record 35 of Set 1 | neryungri
# Processing Record 36 of Set 1 | vila velha
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | hasaki
# Processing Record 39 of Set 1 | sinnamary
# Processing Record 40 of Set 1 | goderich
# Processing Record 41 of Set 1 | usvyaty
# Processing Record 42 of Set 1 | lasa
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | kruisfontein
# Processing Record 45 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 1 | fasa
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | ust-kuyga
# Processing Record 49 of Set 1 | tura
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | kurilsk
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | port hedland
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | buchanan
# Processing Record 6 of Set 2 | norman wells
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | bambous virieux
# Processing Record 9 of Set 2 | satis
# Processing Record 10 of Set 2 | dhidhdhoo
# Processing Record 11 of Set 2 | khani
# Processing Record 12 of Set 2 | ketchikan
# Processing Record 13 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 2 | shingu
# Processing Record 15 of Set 2 | beringovskiy
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | ganzhou
# Processing Record 18 of Set 2 | kavieng
# Processing Record 19 of Set 2 | mumbwa
# Processing Record 20 of Set 2 | auki
# Processing Record 21 of Set 2 | mataura
# Processing Record 22 of Set 2 | abalak
# Processing Record 23 of Set 2 | ilulissat
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 27 of Set 2 | codrington
# Processing Record 28 of Set 2 | westport
# Processing Record 29 of Set 2 | havelock
# Processing Record 30 of Set 2 | bitam
# Processing Record 31 of Set 2 | saint-georges
# Processing Record 32 of Set 2 | raudeberg
# Processing Record 33 of Set 2 | terney
# Processing Record 34 of Set 2 | aklavik
# Processing Record 35 of Set 2 | mendahara
# City not found. Skipping...
# Processing Record 36 of Set 2 | padang
# Processing Record 37 of Set 2 | saskylakh
# Processing Record 38 of Set 2 | isangel
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | taunggyi
# Processing Record 41 of Set 2 | college
# Processing Record 42 of Set 2 | pacific grove
# Processing Record 43 of Set 2 | gaogou
# Processing Record 44 of Set 2 | the valley
# Processing Record 45 of Set 2 | saint-cyr-sur-loire
# Processing Record 46 of Set 2 | airai
# Processing Record 47 of Set 2 | fukue
# Processing Record 48 of Set 2 | druzhinino
# Processing Record 49 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 2 | te anau
# Processing Record 1 of Set 3 | touros
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | atar
# Processing Record 4 of Set 3 | qaqortoq
# Processing Record 5 of Set 3 | taltal
# Processing Record 6 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 3 | ossora
# Processing Record 8 of Set 3 | wagar
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | thunder bay
# Processing Record 11 of Set 3 | ojinaga
# Processing Record 12 of Set 3 | hambantota
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | harper
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | shcherbinka
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | verkh-usugli
# Processing Record 19 of Set 3 | dikson
# Processing Record 20 of Set 3 | leninskoye
# Processing Record 21 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 3 | bolshaya atnya
# City not found. Skipping...
# Processing Record 23 of Set 3 | chapais
# Processing Record 24 of Set 3 | kuminskiy
# Processing Record 25 of Set 3 | lebu
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | tansen
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | artyom
# Processing Record 30 of Set 3 | bredasdorp
# Processing Record 31 of Set 3 | sao filipe
# Processing Record 32 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | cherskiy
# Processing Record 35 of Set 3 | khatanga
# Processing Record 36 of Set 3 | berdigestyakh
# Processing Record 37 of Set 3 | bubaque
# Processing Record 38 of Set 3 | kokstad
# Processing Record 39 of Set 3 | butaritari
# Processing Record 40 of Set 3 | ahipara
# Processing Record 41 of Set 3 | praia da vitoria
# Processing Record 42 of Set 3 | wampusirpi
# City not found. Skipping...
# Processing Record 43 of Set 3 | baykit
# Processing Record 44 of Set 3 | afikpo
# Processing Record 45 of Set 3 | atuona
# Processing Record 46 of Set 3 | rangapara
# Processing Record 47 of Set 3 | winchester
# Processing Record 48 of Set 3 | kodiak
# Processing Record 49 of Set 3 | bonthe
# Processing Record 50 of Set 3 | cabedelo
# Processing Record 1 of Set 4 | university park
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 4 | thompson
# Processing Record 5 of Set 4 | eyl
# Processing Record 6 of Set 4 | lagoa
# Processing Record 7 of Set 4 | north platte
# Processing Record 8 of Set 4 | broome
# Processing Record 9 of Set 4 | schela
# Processing Record 10 of Set 4 | clyde river
# Processing Record 11 of Set 4 | solsvik
# City not found. Skipping...
# Processing Record 12 of Set 4 | luderitz
# Processing Record 13 of Set 4 | sao joao da barra
# Processing Record 14 of Set 4 | katha
# City not found. Skipping...
# Processing Record 15 of Set 4 | katangli
# Processing Record 16 of Set 4 | pakala
# Processing Record 17 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 4 | lazaro cardenas
# Processing Record 19 of Set 4 | ucluelet
# Processing Record 20 of Set 4 | bay roberts
# Processing Record 21 of Set 4 | gat
# Processing Record 22 of Set 4 | santa luzia
# Processing Record 23 of Set 4 | agirish
# Processing Record 24 of Set 4 | shache
# Processing Record 25 of Set 4 | pangody
# Processing Record 26 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 4 | toora-khem
# Processing Record 28 of Set 4 | talnakh
# Processing Record 29 of Set 4 | jalu
# Processing Record 30 of Set 4 | san carlos de bariloche
# Processing Record 31 of Set 4 | bilma
# Processing Record 32 of Set 4 | wakkanai
# Processing Record 33 of Set 4 | mariental
# Processing Record 34 of Set 4 | praia
# Processing Record 35 of Set 4 | tuatapere
# Processing Record 36 of Set 4 | east london
# Processing Record 37 of Set 4 | dromolaxia
# Processing Record 38 of Set 4 | chuy
# Processing Record 39 of Set 4 | cayenne
# Processing Record 40 of Set 4 | arraial do cabo
# Processing Record 41 of Set 4 | teahupoo
# Processing Record 42 of Set 4 | lima
# Processing Record 43 of Set 4 | severo-kurilsk
# Processing Record 44 of Set 4 | cape town
# Processing Record 45 of Set 4 | ixtapa
# Processing Record 46 of Set 4 | nurmijarvi
# Processing Record 47 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 4 | nyzhni sirohozy
# Processing Record 49 of Set 4 | nuuk
# Processing Record 50 of Set 4 | rio grande
# Processing Record 1 of Set 5 | fairbanks
# Processing Record 2 of Set 5 | nikolskoye
# Processing Record 3 of Set 5 | saint george
# Processing Record 4 of Set 5 | northam
# Processing Record 5 of Set 5 | palana
# Processing Record 6 of Set 5 | nouadhibou
# Processing Record 7 of Set 5 | isla mujeres
# Processing Record 8 of Set 5 | bellmead
# Processing Record 9 of Set 5 | acapulco
# Processing Record 10 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 5 | lompoc
# Processing Record 12 of Set 5 | micheweni
# Processing Record 13 of Set 5 | hualmay
# Processing Record 14 of Set 5 | general pico
# Processing Record 15 of Set 5 | imbituba
# Processing Record 16 of Set 5 | grindavik
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | kaitangata
# Processing Record 19 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 5 | divo
# Processing Record 21 of Set 5 | tessalit
# Processing Record 22 of Set 5 | arman
# Processing Record 23 of Set 5 | felanitx
# Processing Record 24 of Set 5 | japura
# Processing Record 25 of Set 5 | pongpong
# City not found. Skipping...
# Processing Record 26 of Set 5 | pandan
# Processing Record 27 of Set 5 | klaksvik
# Processing Record 28 of Set 5 | roald
# Processing Record 29 of Set 5 | idrinskoye
# Processing Record 30 of Set 5 | tabas
# Processing Record 31 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 32 of Set 5 | kununurra
# Processing Record 33 of Set 5 | ust-tsilma
# Processing Record 34 of Set 5 | alyangula
# Processing Record 35 of Set 5 | karaton
# Processing Record 36 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 5 | sao raimundo nonato
# Processing Record 38 of Set 5 | flinders
# Processing Record 39 of Set 5 | bereznik
# Processing Record 40 of Set 5 | kamo
# Processing Record 41 of Set 5 | coquimbo
# Processing Record 42 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 5 | terrace bay
# Processing Record 44 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 5 | lunglei
# Processing Record 46 of Set 5 | nchelenge
# Processing Record 47 of Set 5 | antofagasta
# Processing Record 48 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 49 of Set 5 | voznesenye
# Processing Record 50 of Set 5 | orlik
# Processing Record 1 of Set 6 | san cristobal
# Processing Record 2 of Set 6 | bay city
# Processing Record 3 of Set 6 | brunico
# Processing Record 4 of Set 6 | warrnambool
# Processing Record 5 of Set 6 | margate
# Processing Record 6 of Set 6 | mayo
# Processing Record 7 of Set 6 | wanning
# Processing Record 8 of Set 6 | guerrero negro
# Processing Record 9 of Set 6 | longyearbyen
# Processing Record 10 of Set 6 | quatre cocos
# Processing Record 11 of Set 6 | henties bay
# Processing Record 12 of Set 6 | carnarvon
# Processing Record 13 of Set 6 | baracoa
# Processing Record 14 of Set 6 | erzin
# Processing Record 15 of Set 6 | waingapu
# Processing Record 16 of Set 6 | castro
# Processing Record 17 of Set 6 | san patricio
# Processing Record 18 of Set 6 | young
# Processing Record 19 of Set 6 | pathein
# Processing Record 20 of Set 6 | quatro barras
# Processing Record 21 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 6 | grande prairie
# Processing Record 23 of Set 6 | geraldton
# Processing Record 24 of Set 6 | beloha
# Processing Record 25 of Set 6 | marsh harbour
# Processing Record 26 of Set 6 | freeport
# Processing Record 27 of Set 6 | meulaboh
# Processing Record 28 of Set 6 | diamantino
# Processing Record 29 of Set 6 | avera
# Processing Record 30 of Set 6 | tual
# Processing Record 31 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 32 of Set 6 | sechura
# Processing Record 33 of Set 6 | brigantine
# Processing Record 34 of Set 6 | mulanje
# Processing Record 35 of Set 6 | victoria
# Processing Record 36 of Set 6 | magdagachi
# Processing Record 37 of Set 6 | conceicao do araguaia
# Processing Record 38 of Set 6 | saldanha
# Processing Record 39 of Set 6 | pangoa
# Processing Record 40 of Set 6 | ayan
# Processing Record 41 of Set 6 | portland
# Processing Record 42 of Set 6 | general roca
# Processing Record 43 of Set 6 | san andres
# Processing Record 44 of Set 6 | kouroussa
# Processing Record 45 of Set 6 | yar-sale
# Processing Record 46 of Set 6 | alihe
# Processing Record 47 of Set 6 | jiayuguan
# Processing Record 48 of Set 6 | agadez
# Processing Record 49 of Set 6 | richards bay
# Processing Record 50 of Set 6 | pangnirtung
# Processing Record 1 of Set 7 | tilichiki
# Processing Record 2 of Set 7 | neuquen
# Processing Record 3 of Set 7 | krasnyy chikoy
# Processing Record 4 of Set 7 | nantucket
# Processing Record 5 of Set 7 | thinadhoo
# Processing Record 6 of Set 7 | pisco
# Processing Record 7 of Set 7 | ngunguru
# Processing Record 8 of Set 7 | maniitsoq
# Processing Record 9 of Set 7 | olhao
# Processing Record 10 of Set 7 | hami
# Processing Record 11 of Set 7 | kalmar
# Processing Record 12 of Set 7 | kijang
# Processing Record 13 of Set 7 | san quintin
# Processing Record 14 of Set 7 | salalah
# Processing Record 15 of Set 7 | coihaique
# Processing Record 16 of Set 7 | kidal
# Processing Record 17 of Set 7 | mahebourg
# Processing Record 18 of Set 7 | ribeira grande
# Processing Record 19 of Set 7 | launceston
# Processing Record 20 of Set 7 | monte patria
# Processing Record 21 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 7 | rocha
# Processing Record 23 of Set 7 | dukat
# Processing Record 24 of Set 7 | olafsvik
# Processing Record 25 of Set 7 | vanimo
# Processing Record 26 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 7 | fortuna
# Processing Record 28 of Set 7 | opuwo
# Processing Record 29 of Set 7 | plainview
# Processing Record 30 of Set 7 | chivacoa
# Processing Record 31 of Set 7 | arlit
# Processing Record 32 of Set 7 | mareeba
# Processing Record 33 of Set 7 | inhambane
# Processing Record 34 of Set 7 | pucallpa
# Processing Record 35 of Set 7 | pevek
# Processing Record 36 of Set 7 | gudur
# Processing Record 37 of Set 7 | lukovetskiy
# Processing Record 38 of Set 7 | boyolangu
# Processing Record 39 of Set 7 | ostrovnoy
# Processing Record 40 of Set 7 | kavaratti
# Processing Record 41 of Set 7 | hofn
# Processing Record 42 of Set 7 | usinsk
# Processing Record 43 of Set 7 | itaituba
# Processing Record 44 of Set 7 | batagay-alyta
# Processing Record 45 of Set 7 | bhag
# Processing Record 46 of Set 7 | csabacsud
# City not found. Skipping...
# Processing Record 47 of Set 7 | omboue
# Processing Record 48 of Set 7 | axim
# Processing Record 49 of Set 7 | laguna
# Processing Record 50 of Set 7 | ulladulla
# Processing Record 1 of Set 8 | labuan
# Processing Record 2 of Set 8 | sola
# Processing Record 3 of Set 8 | turukhansk
# Processing Record 4 of Set 8 | fergus falls
# Processing Record 5 of Set 8 | kassala
# Processing Record 6 of Set 8 | jalingo
# Processing Record 7 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 8 | cabimas
# Processing Record 9 of Set 8 | nicoya
# Processing Record 10 of Set 8 | ponta do sol
# Processing Record 11 of Set 8 | matamoros
# Processing Record 12 of Set 8 | cabo rojo
# Processing Record 13 of Set 8 | hassan
# Processing Record 14 of Set 8 | bolu
# Processing Record 15 of Set 8 | mayor pablo lagerenza
# Processing Record 16 of Set 8 | xunchang
# Processing Record 17 of Set 8 | bose
# Processing Record 18 of Set 8 | ambilobe
# Processing Record 19 of Set 8 | kharp
# Processing Record 20 of Set 8 | mehamn
# Processing Record 21 of Set 8 | coruripe
# Processing Record 22 of Set 8 | samarai
# Processing Record 23 of Set 8 | besikduzu
# Processing Record 24 of Set 8 | luba
# Processing Record 25 of Set 8 | banjar
# Processing Record 26 of Set 8 | jewar
# Processing Record 27 of Set 8 | ndele
# Processing Record 28 of Set 8 | bosobolo
# Processing Record 29 of Set 8 | voskresenskoye
# Processing Record 30 of Set 8 | dalnerechensk
# Processing Record 31 of Set 8 | tabou
# Processing Record 32 of Set 8 | kizlyar
# Processing Record 33 of Set 8 | souillac
# Processing Record 34 of Set 8 | vestmannaeyjar
# Processing Record 35 of Set 8 | chimbote
# Processing Record 36 of Set 8 | tokzar
# City not found. Skipping...
# Processing Record 37 of Set 8 | iquitos
# Processing Record 38 of Set 8 | uberaba
# Processing Record 39 of Set 8 | cockburn town
# Processing Record 40 of Set 8 | humberto de campos
# Processing Record 41 of Set 8 | durres
# Processing Record 42 of Set 8 | clarksburg
# Processing Record 43 of Set 8 | namibe
# Processing Record 44 of Set 8 | constitucion
# Processing Record 45 of Set 8 | ulaangom
# Processing Record 46 of Set 8 | port blair
# Processing Record 47 of Set 8 | east grinstead
# Processing Record 48 of Set 8 | at-bashi
# Processing Record 49 of Set 8 | ambon
# Processing Record 50 of Set 8 | komsomolets
# Processing Record 1 of Set 9 | cabo san lucas
# Processing Record 2 of Set 9 | samagaltay
# Processing Record 3 of Set 9 | burica
# City not found. Skipping...
# Processing Record 4 of Set 9 | alice springs
# Processing Record 5 of Set 9 | puerto escondido
# Processing Record 6 of Set 9 | iqaluit
# Processing Record 7 of Set 9 | leningradskiy
# Processing Record 8 of Set 9 | mahajanga
# Processing Record 9 of Set 9 | pangkalanbuun
# Processing Record 10 of Set 9 | baishishan
# Processing Record 11 of Set 9 | ola
# Processing Record 12 of Set 9 | lavrentiya
# Processing Record 13 of Set 9 | riberalta
# Processing Record 14 of Set 9 | severomuysk
# Processing Record 15 of Set 9 | menongue
# Processing Record 16 of Set 9 | xuddur
# Processing Record 17 of Set 9 | brownwood
# Processing Record 18 of Set 9 | pahrump
# Processing Record 19 of Set 9 | shahreza
# Processing Record 20 of Set 9 | moba
# Processing Record 21 of Set 9 | balakhninskiy
# Processing Record 22 of Set 9 | russell
# Processing Record 23 of Set 9 | igrim
# Processing Record 24 of Set 9 | ajaccio
# Processing Record 25 of Set 9 | saint-lo
# Processing Record 26 of Set 9 | pyaozerskiy
# Processing Record 27 of Set 9 | sorland
# Processing Record 28 of Set 9 | mount isa
# Processing Record 29 of Set 9 | kwinana
# Processing Record 30 of Set 9 | whyalla
# Processing Record 31 of Set 9 | cheyenne
# Processing Record 32 of Set 9 | okmulgee
# Processing Record 33 of Set 9 | kurduvadi
# Processing Record 34 of Set 9 | sitka
# Processing Record 35 of Set 9 | namwala
# Processing Record 36 of Set 9 | denpasar
# Processing Record 37 of Set 9 | sokolka
# Processing Record 38 of Set 9 | lamar
# Processing Record 39 of Set 9 | hamilton
# Processing Record 40 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 9 | bengkulu
# Processing Record 42 of Set 9 | bathsheba
# Processing Record 43 of Set 9 | lagos
# Processing Record 44 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 9 | mana
# Processing Record 46 of Set 9 | goure
# Processing Record 47 of Set 9 | asuncion
# Processing Record 48 of Set 9 | benoy
# Processing Record 49 of Set 9 | ancud
# Processing Record 50 of Set 9 | zaragoza
# Processing Record 1 of Set 10 | calvinia
# Processing Record 2 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 10 | caravelas
# Processing Record 4 of Set 10 | andra
# Processing Record 5 of Set 10 | sumbe
# Processing Record 6 of Set 10 | vangaindrano
# Processing Record 7 of Set 10 | los llanos de aridane
# Processing Record 8 of Set 10 | santa ana
# Processing Record 9 of Set 10 | mae sai
# Processing Record 10 of Set 10 | imeni poliny osipenko
# Processing Record 11 of Set 10 | shitanjing
# Processing Record 12 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 10 | san jose
# Processing Record 14 of Set 10 | stokmarknes
# Processing Record 15 of Set 10 | nadbai
# Processing Record 16 of Set 10 | yaroslavskaya
# Processing Record 17 of Set 10 | kagoro
# Processing Record 18 of Set 10 | plettenberg bay
# Processing Record 19 of Set 10 | solnechnyy
# Processing Record 20 of Set 10 | makat
# Processing Record 21 of Set 10 | taruma
# Processing Record 22 of Set 10 | sembe
# Processing Record 23 of Set 10 | darnah
# Processing Record 24 of Set 10 | hervey bay
# Processing Record 25 of Set 10 | rantepao
# Processing Record 26 of Set 10 | tukrah
# Processing Record 27 of Set 10 | esperance
# Processing Record 28 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 10 | saint-pierre
# Processing Record 30 of Set 10 | la ronge
# Processing Record 31 of Set 10 | galesong
# Processing Record 32 of Set 10 | benghazi
# Processing Record 33 of Set 10 | honiara
# Processing Record 34 of Set 10 | tucuman
# Processing Record 35 of Set 10 | aden
# Processing Record 36 of Set 10 | anloga
# Processing Record 37 of Set 10 | aksarka
# Processing Record 38 of Set 10 | lucapa
# Processing Record 39 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 40 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 10 | torbay
# Processing Record 42 of Set 10 | wanaka
# Processing Record 43 of Set 10 | graaff-reinet
# Processing Record 44 of Set 10 | marawi
# Processing Record 45 of Set 10 | rawson
# Processing Record 46 of Set 10 | huanren
# Processing Record 47 of Set 10 | cururupu
# Processing Record 48 of Set 10 | guaymango
# Processing Record 49 of Set 10 | mount gambier
# Processing Record 50 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 11 | saint anthony
# Processing Record 2 of Set 11 | tchaourou
# Processing Record 3 of Set 11 | shkotovo-26
# City not found. Skipping...
# Processing Record 4 of Set 11 | skjold
# Processing Record 5 of Set 11 | manado
# Processing Record 6 of Set 11 | lamu
# Processing Record 7 of Set 11 | kaspiyskiy
# Processing Record 8 of Set 11 | noumea
# Processing Record 9 of Set 11 | chacabuco
# Processing Record 10 of Set 11 | kayes
# Processing Record 11 of Set 11 | schwedt
# Processing Record 12 of Set 11 | novouzensk
# Processing Record 13 of Set 11 | grand gaube
# Processing Record 14 of Set 11 | santa maria
# Processing Record 15 of Set 11 | kenora
# Processing Record 16 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 11 | aktau
# Processing Record 18 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 11 | mandan
# Processing Record 20 of Set 11 | del rio
# Processing Record 21 of Set 11 | halapitan
# Processing Record 22 of Set 11 | camaqua
# Processing Record 23 of Set 11 | thale
# Processing Record 24 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 25 of Set 11 | kisangani
# Processing Record 26 of Set 11 | lysva
# Processing Record 27 of Set 11 | alofi
# Processing Record 28 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 11 | narsaq
# Processing Record 30 of Set 11 | iskateley
# Processing Record 31 of Set 11 | privokzalnyy
# City not found. Skipping...
# Processing Record 32 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 11 | ilhabela
# Processing Record 34 of Set 11 | huai yot
# Processing Record 35 of Set 11 | neiafu
# Processing Record 36 of Set 11 | paidha
# Processing Record 37 of Set 11 | myra
# Processing Record 38 of Set 11 | kasongo-lunda
# Processing Record 39 of Set 11 | suntar
# Processing Record 40 of Set 11 | mackay
# Processing Record 41 of Set 11 | babushkin
# Processing Record 42 of Set 11 | mitsamiouli
# Processing Record 43 of Set 11 | kabarnet
# Processing Record 44 of Set 11 | port keats
# Processing Record 45 of Set 11 | omsukchan
# Processing Record 46 of Set 11 | srednekolymsk
# Processing Record 47 of Set 11 | alvaraes
# Processing Record 48 of Set 11 | waipawa
# Processing Record 49 of Set 11 | fort nelson
# Processing Record 50 of Set 11 | chegdomyn
# Processing Record 1 of Set 12 | port lincoln
# Processing Record 2 of Set 12 | morehead
# Processing Record 3 of Set 12 | okha
# Processing Record 4 of Set 12 | kushiro
# Processing Record 5 of Set 12 | evensk
# Processing Record 6 of Set 12 | basyanovskiy
# City not found. Skipping...
# Processing Record 7 of Set 12 | ayagoz
# Processing Record 8 of Set 12 | malacacheta
# Processing Record 9 of Set 12 | matara
# Processing Record 10 of Set 12 | bara
# Processing Record 11 of Set 12 | dali
# Processing Record 12 of Set 12 | terrace
# Processing Record 13 of Set 12 | itoman
# Processing Record 14 of Set 12 | port hardy
# Processing Record 15 of Set 12 | gzhatsk
# City not found. Skipping...
# Processing Record 16 of Set 12 | adrar
# Processing Record 17 of Set 12 | malartic
# Processing Record 18 of Set 12 | birjand
# Processing Record 19 of Set 12 | tautira
# Processing Record 20 of Set 12 | eureka
# Processing Record 21 of Set 12 | vostok
# Processing Record 22 of Set 12 | saucillo
# Processing Record 23 of Set 12 | portadown
# Processing Record 24 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 25 of Set 12 | dinguiraye
# Processing Record 26 of Set 12 | vavuniya
# Processing Record 27 of Set 12 | naze
# Processing Record 28 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 12 | husavik
# Processing Record 30 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 31 of Set 12 | omachi
# Processing Record 32 of Set 12 | kudahuvadhoo
# Processing Record 33 of Set 12 | boundiali
# Processing Record 34 of Set 12 | iwanai
# Processing Record 35 of Set 12 | otacilio costa
# Processing Record 36 of Set 12 | honningsvag
# Processing Record 37 of Set 12 | palauig
# Processing Record 38 of Set 12 | anju
# Processing Record 39 of Set 12 | san felipe
# Processing Record 40 of Set 12 | matay
# Processing Record 41 of Set 12 | kodino
# Processing Record 42 of Set 12 | luanda
# Processing Record 43 of Set 12 | port-cartier
# Processing Record 44 of Set 12 | boden
# Processing Record 45 of Set 12 | medveda
# Processing Record 46 of Set 12 | aosta
# Processing Record 47 of Set 12 | tekeli
# Processing Record 48 of Set 12 | sal rei
# Processing Record 49 of Set 12 | tomohon
# Processing Record 50 of Set 12 | north bend
# Processing Record 1 of Set 13 | atasu
# Processing Record 2 of Set 13 | takoradi
# Processing Record 3 of Set 13 | qabis
# City not found. Skipping...
# Processing Record 4 of Set 13 | warmbad
# Processing Record 5 of Set 13 | yerbogachen
# Processing Record 6 of Set 13 | trat
# Processing Record 7 of Set 13 | nemuro
# Processing Record 8 of Set 13 | rapid city
# Processing Record 9 of Set 13 | zambezi
# Processing Record 10 of Set 13 | jinka
# Processing Record 11 of Set 13 | la macarena
# Processing Record 12 of Set 13 | dawei
# Processing Record 13 of Set 13 | hobyo
# Processing Record 14 of Set 13 | vila
# Processing Record 15 of Set 13 | karasjok
# Processing Record 16 of Set 13 | baculin
# Processing Record 17 of Set 13 | sept-iles
# Processing Record 18 of Set 13 | lucea
# Processing Record 19 of Set 13 | privas
# Processing Record 20 of Set 13 | namatanai
# Processing Record 21 of Set 13 | vuktyl
# Processing Record 22 of Set 13 | yeppoon
# Processing Record 23 of Set 13 | bemidji
# Processing Record 24 of Set 13 | dharchula
# Processing Record 25 of Set 13 | plyussa
# Processing Record 26 of Set 13 | thap than
# Processing Record 27 of Set 13 | angren
# Processing Record 28 of Set 13 | mugango
# Processing Record 29 of Set 13 | batamshinskiy
# Processing Record 30 of Set 13 | kondinskoye
# Processing Record 31 of Set 13 | vung tau
# Processing Record 32 of Set 13 | bonavista
# Processing Record 33 of Set 13 | polunochnoye
# Processing Record 34 of Set 13 | athabasca
# Processing Record 35 of Set 13 | ishigaki
# Processing Record 36 of Set 13 | ugoofaaru
# Processing Record 37 of Set 13 | soufriere
# Processing Record 38 of Set 13 | maceo
# Processing Record 39 of Set 13 | sangar
# Processing Record 40 of Set 13 | buon me thuot
# City not found. Skipping...
# Processing Record 41 of Set 13 | xinxiang
# Processing Record 42 of Set 13 | winnemucca
# Processing Record 43 of Set 13 | okhotsk
# Processing Record 44 of Set 13 | lodwar
# Processing Record 45 of Set 13 | tokur
# Processing Record 46 of Set 13 | zyryanovsk
# Processing Record 47 of Set 13 | stephenville
# Processing Record 48 of Set 13 | lata
# Processing Record 49 of Set 13 | karak
# Processing Record 50 of Set 13 | libreville
# Processing Record 1 of Set 14 | aloleng
# Processing Record 2 of Set 14 | poum
# Processing Record 3 of Set 14 | yumen
# Processing Record 4 of Set 14 | kupino
# Processing Record 5 of Set 14 | mapiripan
# Processing Record 6 of Set 14 | tabora
# Processing Record 7 of Set 14 | andenes
# Processing Record 8 of Set 14 | bandarbeyla
# Processing Record 9 of Set 14 | great bend
# Processing Record 10 of Set 14 | parana
# Processing Record 11 of Set 14 | vrangel
# Processing Record 12 of Set 14 | kangaatsiaq
# Processing Record 13 of Set 14 | kaset sombun
# Processing Record 14 of Set 14 | port macquarie
# Processing Record 15 of Set 14 | krasnovishersk
# Processing Record 16 of Set 14 | minab
# Processing Record 17 of Set 14 | algiers
# Processing Record 18 of Set 14 | bilibino
# Processing Record 19 of Set 14 | zaliztsi
# Processing Record 20 of Set 14 | piracanjuba
# Processing Record 21 of Set 14 | maceio
# Processing Record 22 of Set 14 | naryan-mar
# Processing Record 23 of Set 14 | nanortalik
# Processing Record 24 of Set 14 | pietersburg
# Processing Record 25 of Set 14 | bijar
# Processing Record 26 of Set 14 | camacha
# Processing Record 27 of Set 14 | wynyard
# Processing Record 28 of Set 14 | lufilufi
# Processing Record 29 of Set 14 | kachikau
# City not found. Skipping...
# Processing Record 30 of Set 14 | ust-maya
# Processing Record 31 of Set 14 | maravilha
# Processing Record 32 of Set 14 | san rafael
# Processing Record 33 of Set 14 | flin flon
# Processing Record 34 of Set 14 | bethanien
# Processing Record 35 of Set 14 | fez
# Processing Record 36 of Set 14 | nelson bay
# Processing Record 37 of Set 14 | semirom
# Processing Record 38 of Set 14 | bima
# Processing Record 39 of Set 14 | coihueco
# Processing Record 40 of Set 14 | moose factory
# Processing Record 41 of Set 14 | cervo
# Processing Record 42 of Set 14 | makushino
# Processing Record 43 of Set 14 | sandwick
# Processing Record 44 of Set 14 | saint-joseph
# Processing Record 45 of Set 14 | panguna
# Processing Record 46 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 47 of Set 14 | vardo
# Processing Record 48 of Set 14 | dalhousie
# Processing Record 49 of Set 14 | sosnogorsk
# Processing Record 50 of Set 14 | benguela
# Processing Record 1 of Set 15 | krasnaya poyma
# Processing Record 2 of Set 15 | makakilo city
# Processing Record 3 of Set 15 | yaan
# Processing Record 4 of Set 15 | suzu
# City not found. Skipping...
# Processing Record 5 of Set 15 | nome
# Processing Record 6 of Set 15 | tynset
# Processing Record 7 of Set 15 | boddam
# Processing Record 8 of Set 15 | krasnoselkup
# Processing Record 9 of Set 15 | half moon bay
# Processing Record 10 of Set 15 | tramagal
# Processing Record 11 of Set 15 | craig
# Processing Record 12 of Set 15 | west wendover
# Processing Record 13 of Set 15 | san-pedro
# Processing Record 14 of Set 15 | barcelos
# Processing Record 15 of Set 15 | totma
# Processing Record 16 of Set 15 | amahai
# Processing Record 17 of Set 15 | nizhniy odes
# Processing Record 18 of Set 15 | shar
# Processing Record 19 of Set 15 | tezu
# Processing Record 20 of Set 15 | taksimo
# Processing Record 21 of Set 15 | tshikapa
# Processing Record 22 of Set 15 | primo tapia
# Processing Record 23 of Set 15 | doha
# Processing Record 24 of Set 15 | santiago del estero
# Processing Record 25 of Set 15 | twin falls
# Processing Record 26 of Set 15 | araouane
# Processing Record 27 of Set 15 | krasnyy kut
# Processing Record 28 of Set 15 | pakokku
# Processing Record 29 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 30 of Set 15 | san clemente
# Processing Record 31 of Set 15 | taft
# Processing Record 32 of Set 15 | tra vinh
# Processing Record 33 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 15 | hachinohe
# Processing Record 35 of Set 15 | lyubim
# Processing Record 36 of Set 15 | puerto leguizamo
# Processing Record 37 of Set 15 | lekoni
# Processing Record 38 of Set 15 | petukhovo
# Processing Record 39 of Set 15 | inuvik
# Processing Record 40 of Set 15 | kushima
# Processing Record 41 of Set 15 | grafton
# Processing Record 42 of Set 15 | sobolevo
# Processing Record 43 of Set 15 | elizabeth city
# Processing Record 44 of Set 15 | usevya
# Processing Record 45 of Set 15 | uruzgan
# Processing Record 46 of Set 15 | kaeo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Rikitea -23.1203 -134.9692     78.22        71          87        9.57
# 1      Lensk  60.7253  114.9278      8.58        93          99        5.99
# 2    Rosetta  31.4044   30.4164     57.02        63          79       25.34
# 3  Jamestown  42.0970  -79.2353     21.09        62         100        5.01
# 4   Vallenar -28.5708  -70.7581     84.92        18           0       10.22
# 5      Vaini -21.2000 -175.2000     79.68        84         100       20.71
# 6     Faanui -16.4833 -151.7500     80.44        73          19       14.70
# 7       Brae  60.3964   -1.3530     37.31        62         100       34.45
# 8     Urumqi  43.8010   87.6005     -1.25        85          75        2.24
# 9       Hilo  19.7297 -155.0900     68.11        74          40        9.22
#
#   Country Current Description                 Date
# 0      PF          light rain  2022-02-04 16:40:00
# 1      RU     overcast clouds  2022-02-04 16:43:22
# 2      EG       broken clouds  2022-02-04 16:43:22
# 3      US                mist  2022-02-04 16:42:35
# 4      CL           clear sky  2022-02-04 16:43:23
# 5      TO          light rain  2022-02-04 16:43:23
# 6      PF          few clouds  2022-02-04 16:43:23
# 7      GB     overcast clouds  2022-02-04 16:43:24
# 8      CN                 fog  2022-02-04 16:43:24
# 9      US    scattered clouds  2022-02-04 16:42:43

# %%
#Creating the new column order
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# %%
#Applying the new column order
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Rikitea      PF -23.1203 -134.9692     78.22        71          87
# 1      Lensk      RU  60.7253  114.9278      8.58        93          99
# 2    Rosetta      EG  31.4044   30.4164     57.02        63          79
# 3  Jamestown      US  42.0970  -79.2353     21.09        62         100
# 4   Vallenar      CL -28.5708  -70.7581     84.92        18           0
# 5      Vaini      TO -21.2000 -175.2000     79.68        84         100
# 6     Faanui      PF -16.4833 -151.7500     80.44        73          19
# 7       Brae      GB  60.3964   -1.3530     37.31        62         100
# 8     Urumqi      CN  43.8010   87.6005     -1.25        85          75
# 9       Hilo      US  19.7297 -155.0900     68.11        74          40
#
#    Wind Speed Current Description
# 0        9.57          light rain
# 1        5.99     overcast clouds
# 2       25.34       broken clouds
# 3        5.01                mist
# 4       10.22           clear sky
# 5       20.71          light rain
# 6       14.70          few clouds
# 7       34.45     overcast clouds
# 8        2.24                 fog
# 9        9.22    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Deliverable_Data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
